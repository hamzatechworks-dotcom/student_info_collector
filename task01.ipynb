# %%
# Student Information Collector Pro

student_id = "STD-2026-001"

student_name = input("Enter Student Name: ")
father_name = input("Enter Father's Name: ")
age = int(input("Enter Age: "))
gender = input("Enter Gender: ")
city = input("Enter City: ")

matric_marks = float(input("Enter Matric Marks (Out of 1100): "))
fsc_marks = float(input("Enter FSc Marks (Out of 1100): "))
# Out:
# Enter Student Name: Hamza
# Enter Father's Name: arif
# Enter Age: 21
# Enter Gender: male
# Enter City: multan
# Enter Matric Marks (Out of 1100): 1096
# Enter FSc Marks (Out of 1100): 946

# %%
matric_percentage = (matric_marks / 1100) * 100
fsc_percentage = (fsc_marks / 1100) * 100

average_percentage = (matric_percentage + fsc_percentage) / 2

# %%
if average_percentage >= 70:
    scholarship_status = "Eligible for Scholarship"
else:
    scholarship_status = "Not Eligible"

# %%
print("=" * 40)
print("        STUDENT PROFILE")
print("=" * 40)

print(f"Student ID : {student_id}")
print(f"Student Name : {student_name}")
print(f"Father's Name : {father_name}")
print(f"Age : {age} Years")
print(f"Gender : {gender}")
print(f"City : {city}")

print(f"Matric Marks : {matric_marks} / 1100")
print(f"FSc Marks : {fsc_marks} / 1100")

print(f"Matric Percentage : {matric_percentage:.2f}%")
print(f"FSc Percentage : {fsc_percentage:.2f}%")
print(f"Average Percentage : {average_percentage:.2f}%")

print(f"Scholarship Status : {scholarship_status}")
# Out:
# ========================================
#         STUDENT PROFILE
# ========================================
# Student ID : STD-2026-001
# Student Name : Hamza
# Father's Name : arif
# Age : 21 Years
# Gender : male
# City : multan
# Matric Marks : 1096.0 / 1100
# FSc Marks : 946.0 / 1100
# Matric Percentage : 99.64%
# FSc Percentage : 86.00%
# Average Percentage : 92.82%
# Scholarship Status : Eligible for Scholarship

# %%
prefix = "STD"
year = "2026"
number = "001"

student_id = f"{prefix}-{year}-{number}"

# %%
print(f"Student ID : {student_id}")
# Out:
# Student ID : STD-2026-001

# %%
#----challenge-------

# %%
student_name = student_name.upper()

# %%
print(f"Student Name : {student_name}")
# Out:
# Student Name : HAMZA

# %%
print(f"Length of Student Name : {len(student_name)}")
# Out:
# Length of Student Name : 5
